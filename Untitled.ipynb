# %%
send
# Out:
# [res:Block]

# %%
'test'
# Out:
# test

# %%
File new: '~/Desktop/emoji/bruh.png'
# Out:
# [Object]

# %%
Display['test', \plain]
# Out:
# test

# %%
Display['<html><b>help</b></html>', \html]
# Out:
# [Object]

# %%
Display[[['id', 'name'], [1, 'test'], [2, 'semi']], \table]
# Out:
# [Object]

# %%
Display[JupyterPen, \inspect]
# Out:
# [Object]

# %%
Display[Display, \inspect]
# Out:
# [Object]

# %%
Plot new: {
          title: 'Sine Wave Example'.
      xrange: '[-10:10]'.
      ylabel: 'x'.
      xlabel: 'sin(x)'.

      var x is (0..50) toArray.
      var y is x fmap: \:x x pow: 2.
      var y2 is x fmap: \:x x sin abs.

      data: [
        (DataSet new init: 'sin(x)' withBlock: {
          with: 'lines'.
          title: 'String function'.
          linewidth: 4.
        }),
        (DataSet new init: [x, y] withBlock: {
          with: 'linespoints'.
          title: 'Array data'.
        }),
        (DataSet new init: [x, y2] withBlock: {
          with: 'lines'.
          title: 'Array data |sin(x)|'.
        })
      ].
}
# Out:
# [Object]

# %%
Display[?>
    <html>
    <head>
        <title>My Sample Project</title>
        <script src="http://cdnjs.cloudflare.com/ajax/libs/require.js/2.1.16/require.js"></script>
    </head>
    <body>
        <h1>Demo for svg-pan-zoom: Using Require.js</h1>
        <embed id="demo-tiger" type="image/svg+xml" src="https://cdn.rawgit.com/ariutta/svg-pan-zoom/master/demo/tiger.svg" style="width: 500px; height: 500px; border:1px solid black; ">Your browser does not support SVG</embed>
                </body>
                <script>
                require.config({
  paths: {
    'svg-pan-zoom': '//cdn.rawgit.com/ariutta/svg-pan-zoom/master/dist/svg-pan-zoom'
  }
})

require(["svg-pan-zoom"], function(svgPanZoom) {
    let s = document.getElementById('demo-tiger');
    console.log(s);
  svgPanZoom(s, {
    zoomEnabled: true,
    controlIconsEnabled: true
  });
});
                </script>
</html>
<?, \html]
# Out:
# [Object]

# %%
'test'
# Out:
# test

# %%
: ls
# Out:
# citron
# example.ipynb
# ICitronModules
# images
# install_script.sh
# README.md
# Untitled3.ipynb
# Untitled.ipynb
# Utils

# %%
: pacman -Ss citron

# %%
:time 1 + 2
# Out:
# 3
# Execution took 213 cycles

# %%
:time 1 + 2
# Out:
# 3
# Execution took 339 cycles

# %%
:time 1 + 2
# Out:
# 3
# Execution took 218 cycles

# %%
:time 1 - 2
# Out:
# -1
# Execution took 213 cycles
